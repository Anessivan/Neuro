# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import ensemble

n, m = (10, 20)

# l1 = 
# l2 = np.pi - 2*np.arcsin(0.9)
l1 = 0
l2 = np.pi - 2*np.arcsin(0.97)

plt.figure(figsize=[30, 30])

for i, d in enumerate(np.linspace(0, 1, num=n)):
    for j, sigma in enumerate(np.linspace(l1, l2, num=m)):
        t, x, y = ensemble.compute_ensemble(d, sigma)
        # print(5*i+j+1)
        plt.subplot(n, m, m*i+j+1)
        plt.plot([i % (2*np.pi) for i in x], [i % (2*np.pi) for i in y])
        if i == 0:
            plt.title("s={:.3f}".format(sigma))
        if j == 0:
            plt.ylabel("d={:.3f}".format(d))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import ensemble

t, x, y = ensemble.compute_ensemble(0.444, 0.491)
plt.plot(t, [i % (2*np.pi) for i in y])

# %%
plt.plot(t, x)

# %%
plt.plot(x, y)

# %%
plt.plot(t, x_)

# %%
plt.plot(t, y)

# %%
plt.plot(t, y_)

# %%
t=list()
x=list()
x_=list()
y=list()
y_=list()

with open("One.txt") as f:
    for line in f:
        _t, _x, _x_ = map(float, line.split())
        t.append(_t)
        x.append(_x)
        x_.append(_x_)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3116/388295945.py in <module>
#       5 y_=list()
#       6
# ----> 7 with open("One.txt") as f:
#       8     for line in f:
#       9         _t, _x, _x_ = map(float, line.split())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'One.txt'

# %%
plt.plot(x[100:120], y[100:120])

# %%
plt.plot(t, x_)
